# %%
import pandas as pd
import datetime
import sqlite3
import pymysql
import pandas.io.sql as psql
from datetime import datetime as dt
import numpy as np
import pandas.tseries.offsets as offsets
# # import sqlalchemy as sqa

# import matplotlib.pyplot as plt
import python_ss.python_ss as ps
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import json

import os
import ast
import db_dtypes
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud import secretmanager

import socket
import python_ss.python_ss as ps

# %%
def access_secret_version(project_id, secret_id, version_id='latest'):
    client = secretmanager.SecretManagerServiceClient()

    name = f"projects/{project_id}/secrets/{secret_id}/versions/{version_id}"
    response = client.access_secret_version(request={"name": name})
    payload = response.payload.data.decode("UTF-8")
    return ast.literal_eval(payload)

# %%
# 上記関数を実行するコードが記載されています。こちらもそのままお使いください。
credentials = service_account.Credentials.from_service_account_info(
  access_secret_version('temp-for-sandbox', 'TEMP_CREDENTIAL_KEY'),
  scopes=["https://www.googleapis.com/auth/cloud-platform"],)
# Out:
# z:\Users\suehara\Documents\python\analysis\.venv\Lib\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
# 上記関数を実行するコードが記載されています。こちらもそのままお使いください。
credentials = service_account.Credentials.from_service_account_info(
access_secret_version('r-group-bigdata', 'CREDENTIALS_SECRET_KEY_WORKER'),
scopes=["https://www.googleapis.com/auth/cloud-platform"],)

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 広告情報取得

# %%
#最後のIDを取得する
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID = '14vXxjcdlyY463QjrtEnCw7pJ0oLStXZD8Q42IdW2Zd4'
Sheet_NAME = '候補者マスタ!A'
Sheet_row = ":M"
RANGE_NAME = Sheet_NAME+Sheet_row
adinfo = ps.get_ss(SPREADSHEET_ID,RANGE_NAME,service)

# %%
adinfoA = adinfo.copy()

# %%
adinfoA.replace([np.inf, -np.inf], np.nan, inplace=True)
adinfoA.fillna('', inplace=True)
adinfoA = adinfoA.values.tolist()

# %%
#【主要媒体別】成約単価管理表【NEO】にコピペ
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID = '1Mvqe8nLhdiT9acCMA4cP-4MH5X4GmYPiC9OSqHTEHtk'
service = ps.get_auth(SCOPES, json_path)
Sheet_NAME = 'user!A'
Sheet_row = '2'
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,adinfoA,service)

# %%
adinfoA
# Out:
# [['1070',
#   '2016/09/17',
#   'ロンザン',
#   '2020/05/20',
#   'ZOOM',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '49',
#   '部長クラス'],
#  ['2748',
#   '2017/02/06',
#   'ロンザン',
#   '2017/02/06',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '59',
#   '役員クラス'],
#  ['7024',
#   '2017/08/07',
#   'ロンザン',
#   '2017/08/07',
#   '',
#   '',
#   'google_SHIMEI / cpc',
#   '(not set)',
#   '(not set)',
#   '(not set)',
#   '',
#   '55',
#   'リーダークラス'],
#  ['8539',
#   '2017/09/15',
#   'レイノス',
#   '2017/09/15',
#   '',
#   '',
#   'fb_ad / display',
#   '(not set)',
#   '(not set)',
#   '(not set)',
#   '',
#   '35',
#   'リーダークラス'],
#  ['9502',
#   '2017/10/05',
#   'レイノス',
#   '2017/10/05',
#   '0',
#   '',
#   'yahoo_Ten / cpc_CA',
#   '(not set)',
#   '(not set)',
#   '(not set)',
#   '',
#   '45',
#   '役員クラス'],
#  ['11522',
#   '2017/11/20',
#   'ロンザン',
#   '2017/11/20',
#   '0',
#   '',
#   'Indeed / cpc',
#   'Indeed',
#   '(not set)',
#   '(not set)',
#   '',
# ...

# %%
#CAシートにコピペ
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID = '1d1uYQMCIhJGMlUe4S8m56Bd_ZS4_V-FUEtPjUlgpn9Y'
service = ps.get_auth(SCOPES, json_path)
Sheet_NAME = 'user!A'
Sheet_row = '2'
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,adinfoA,service)

# %%
adinfoA
# Out:
# [['1070',
#   '2016/09/17',
#   'ロンザン',
#   '2020/05/20',
#   'ZOOM',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '49',
#   '部長クラス'],
#  ['2748',
#   '2017/02/06',
#   'ロンザン',
#   '2017/02/06',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '59',
#   '役員クラス'],
#  ['7024',
#   '2017/08/07',
#   'ロンザン',
#   '2017/08/07',
#   '',
#   '',
#   'google_SHIMEI / cpc',
#   '(not set)',
#   '(not set)',
#   '(not set)',
#   '',
#   '55',
#   'リーダークラス'],
#  ['8539',
#   '2017/09/15',
#   'レイノス',
#   '2017/09/15',
#   '',
#   '',
#   'fb_ad / display',
#   '(not set)',
#   '(not set)',
#   '(not set)',
#   '',
#   '35',
#   'リーダークラス'],
#  ['9502',
#   '2017/10/05',
#   'レイノス',
#   '2017/10/05',
#   '0',
#   '',
#   'yahoo_Ten / cpc_CA',
#   '(not set)',
#   '(not set)',
#   '(not set)',
#   '',
#   '45',
#   '役員クラス'],
#  ['11522',
#   '2017/11/20',
#   'ロンザン',
#   '2017/11/20',
#   '0',
#   '',
#   'Indeed / cpc',
#   'Indeed',
#   '(not set)',
#   '(not set)',
#   '',
# ...

# %%
#ZEALSシートにコピペ
SPREADSHEET_ID = '1EglGY_Lf1kvHqZTpow4F2ksD20xD9J8G1oaMIjtyj78'
service = ps.get_auth(SCOPES, json_path)
Sheet_NAME = 'user!A'
Sheet_row = '2'
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,adinfoA,service)

# %% [markdown]
# ## 広告費

# %%
#LINE広告費を取得する
SPREADSHEET_ID = '14vXxjcdlyY463QjrtEnCw7pJ0oLStXZD8Q42IdW2Zd4'
Sheet_NAME = '広告費!A'
Sheet_row = ":T"
RANGE_NAME = Sheet_NAME+Sheet_row
adcost = ps.get_ss(SPREADSHEET_ID,RANGE_NAME,service)

# %%
adcost_nm = adcost.copy()

# %%
adcost_line = adcost[["date","LINE CPC","LINE リタゲ","LINE CPF"]]
adcost_line
# Out:
#             date LINE CPC LINE リタゲ LINE CPF
# 1     2019/01/01                 0
# 2     2019/01/02                 0
# 3     2019/01/03                 0
# 4     2019/01/04                 0
# 5     2019/01/05                 0
# ...          ...      ...      ...      ...
# 4210  2030/07/11                 0
# 4211  2030/07/12                 0
# 4212  2030/07/13                 0
# 4213  2030/07/14                 0
# 4214  2030/07/15                 0
#
# [4214 rows x 4 columns]

# %%
adcost_nm.replace([np.inf, -np.inf], np.nan, inplace=True)
adcost_nm.fillna('', inplace=True)
adcost_nm = adcost_nm.values.tolist()

adcost_line.replace([np.inf, -np.inf], np.nan, inplace=True)
adcost_line.fillna('', inplace=True)
adcost_line = adcost.values.tolist()
# Out:
# C:\Users\suehara\AppData\Local\Temp\ipykernel_32552\3808569263.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adcost_line.replace([np.inf, -np.inf], np.nan, inplace=True)
# C:\Users\suehara\AppData\Local\Temp\ipykernel_32552\3808569263.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adcost_line.fillna('', inplace=True)

# %%
#LINEシートへコピペ
SPREADSHEET_ID = '1EglGY_Lf1kvHqZTpow4F2ksD20xD9J8G1oaMIjtyj78'
service = ps.get_auth(SCOPES, json_path)
Sheet_NAME = '広告費!A'
Sheet_row = '2'
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,adcost_nm,service)

# %%
#NMシートコピペ
SPREADSHEET_ID = '1d1uYQMCIhJGMlUe4S8m56Bd_ZS4_V-FUEtPjUlgpn9Y'
service = ps.get_auth(SCOPES, json_path)
Sheet_NAME = 'adcost!A'
Sheet_row = '2'
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,adcost_nm,service)

# %%
#CAシートコピペ
SPREADSHEET_ID = '1fVbpOYwIRsbW69EDsbJlTJwJVPTexi8RoMd3ahiO-IA'
service = ps.get_auth(SCOPES, json_path)
Sheet_NAME = '広告費!A'
Sheet_row = '2'
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,adcost_nm,service)

# %% [markdown]
# ## 初期交渉情報取得

# %%
adinfoB = adinfo.copy()

# %%
adinfoB
# Out:
#       tenki_id        登録日時   フリ先       手上げ日付  本手上げ       KN共有日  \
# 1         1070  2016/09/17  ロンザン  2020/05/20  ZOOM
# 2         2748  2017/02/06  ロンザン  2017/02/06
# 3         7024  2017/08/07  ロンザン  2017/08/07
# 4         8539  2017/09/15  レイノス  2017/09/15
# 5         9502  2017/10/05  レイノス  2017/10/05     0
# ...        ...         ...   ...         ...   ...         ...
# 85875   140722  2026/07/20  ロンザン  2026/07/21  TRUE  2026/07/21
# 85876   140723  2026/07/21  ロンザン  2026/07/21  TRUE  2026/07/21
# 85877   140724  2026/07/21
# 85878   140725  2026/07/21  ロンザン  2026/07/21  TRUE  2026/07/21
# 85879   140726  2026/07/21  ロンザン  2026/07/21  TRUE  2026/07/21
#
#                      参照元/メディア     キャンペーン       広告ID        KWD          年齢  \
# 1                                                                       49
# 2                                                                       59
# 3         google_SHIMEI / cpc  (not set)  (not set)  (not set)          55
# ...

# %%
rzshokikosho_query = """
WITH
-- ステップ1: 必要なテーブルをJOINし、各レコードの基本情報を計算
base_data AS (
  SELECT
    s.kohosha_id,
    k.tenki_id,
    s.kosho_setteibi,
    s.kosho_yoteibi,
    s.kosho_jisshibi,
    s.kosho_seq,
    s.cxl_riyu,
    -- APsource: 複数の名称を'その他'にまとめるなど、カテゴリを整形
    CASE
      WHEN consts1.name IN ('HP反響', '上場企業役員DM', 'Gアポ') THEN 'その他'
      WHEN consts1.name = '社外取締役名鑑　候補者' THEN '顧問名鑑登録　解放者'
      ELSE consts1.name
    END AS APsource,
    syi2.sei_plus AS ap_kakutokusha,
    -- 面談担当者: syainテーブルに存在すればsei_plusを、なければ元のIDを使用
    COALESCE(syi1.sei_plus, s.mendan_tanto) AS mendan_tanto,
    -- 実施ステータス: フラグ値などを元に分かりやすい文字列に変換
    CASE
      WHEN s.kosho_yoteibi >= CURRENT_DATE('Asia/Tokyo') THEN '実施前'
      WHEN s.jisshi_flag = 2 AND s.deleted = 2 THEN 'CXL'
      WHEN s.jisshi_flag = 0 AND s.deleted = 0 AND s.nittei_chosei = 1 THEN '日程調整中'
      WHEN s.jisshi_flag = 1 THEN '実施'
      WHEN s.jisshi_flag = 0 THEN '未報告'
      ELSE CAST(s.jisshi_flag AS STRING)
    END AS jisshi,
    -- 移籍意欲: 新しい値があれば優先し、なければ古い値を使用
    COALESCE(consts2.name, consts3.name) AS iseki_iyoku,
    -- 前回実施日からの経過日数: LAG関数で候補者ごとに前回交渉の実施日を取得して計算
    DATE_DIFF(s.kosho_setteibi, LAG(s.kosho_jisshibi) OVER (PARTITION BY s.kohosha_id ORDER BY s.kosho_jisshibi), DAY) AS keikabi
  FROM
    `r-group-bigdata..live_rhs.shokikoshos` AS s
    LEFT JOIN `r-group-bigdata.live_rhs.kohoshas` AS k ON s.kohosha_id = k.id
    LEFT JOIN `r-group-bigdata.live_company.syain` AS syi1 ON s.mendan_tanto = syi1.user_id
    LEFT JOIN `r-group-bigdata.live_company.syain` AS syi2 ON s.ap_kakutoku = syi2.user_id
    -- sys_constsテーブルへのJOINを最適化。必要なgroup_codeごとにJOINを分ける
    LEFT JOIN `r-group-bigdata.live_rhs.sys_consts` AS consts1 ON s.ap_source = consts1.code AND consts1.group_code = 19
    LEFT JOIN `r-group-bigdata.live_rhs.sys_consts` AS consts2 ON k.iseki_iyoku_new = consts2.code AND consts2.group_code = 5100
    LEFT JOIN `r-group-bigdata.live_rhs.sys_consts` AS consts3 ON s.iseki_iyoku = consts3.code AND consts3.group_code = 5100
),

-- ステップ2: ステップ1で計算したAPsourceを元に、前回からの変更を検知
final_data AS (
  SELECT
    *,
    -- APsourceが前回から変更されたかのフラグを計算
    CASE
      -- LAG関数で取得した1つ前のAPsourceと比較
      WHEN APsource != LAG(APsource) OVER (PARTITION BY kohosha_id ORDER BY kosho_setteibi) THEN 1
      ELSE 0
    END AS APS_change
  FROM
    base_data
)

-- 最終的なアウトプット: 必要なカラムを選択し、最終的なフラグを計算
SELECT
  kohosha_id,
  tenki_id,
  APsource,
  ap_kakutokusha,
  mendan_tanto,
  kosho_setteibi,
  kosho_yoteibi,
  kosho_jisshibi,
  jisshi,
  kosho_seq,
  APS_change,
  -- 再フラグ: 複数の条件に基づいてフラグを立てる
  CASE
    WHEN kosho_seq = 1 THEN 1       -- 最初の交渉
    WHEN APS_change = 1 THEN 1     -- APsourceが変更された場合
    WHEN keikabi > 90 THEN 2       -- 前回の交渉から90日以上経過した場合
    ELSE 0
  END AS sai_flg,
  cxl_riyu,
  iseki_iyoku
FROM
  final_data
WHERE
  -- 元のクエリと同じフィルタ条件
  APsource = '転機社長名鑑'
  AND kosho_setteibi >= DATE '2019-09-30'
ORDER BY
  kosho_setteibi ASC;
"""

client = bigquery.Client(credentials=credentials, project=credentials.project_id)
rzshokikosho = client.query(rzshokikosho_query).result().to_dataframe()

# %%
adinfoB = adinfoB.rename(columns={"ID":"tenki_id"})
rzshokikosho["tenki_id"] = rzshokikosho["tenki_id"].astype(str)
shokikosho = pd.merge(rzshokikosho,adinfoB,on=("tenki_id"),how=("left"))

# %%
rzshokikosho
# Out:
#        kohosha_id tenki_id APsource ap_kakutokusha   mendan_tanto  \
# 0           14985    44305   転機社長名鑑            内藤ち            勝股大
# 1           15003    46161   転機社長名鑑            内藤ち            三木茉
# 2           15002    46151   転機社長名鑑            内藤ち           山田真２
# 3           15001    46191   転機社長名鑑            内藤ち            松島せ
# 4           15000    46144   転機社長名鑑            内藤ち            運上禎
# ...           ...      ...      ...            ...            ...
# 38993       77333   140692   転機社長名鑑            内藤ち            前川天
# 38994       77334   140439   転機社長名鑑            内藤ち             森俊
# 38995       77335   140719   転機社長名鑑            内藤ち            松澤神
# 38996       77336   140733   転機社長名鑑            内藤ち  aya-takeshita
# 38997       37531    97888   転機社長名鑑            前川天            前川天
#
#       kosho_setteibi kosho_yoteibi kosho_jisshibi jisshi  kosho_seq  \
# 0         2019-09-30    2019-10-01     2019-10-01     実施          1
# ...

# %%
rzshokikosho = shokikosho[['tenki_id','登録日時','kosho_setteibi','kosho_jisshibi', '参照元/メディア','キャンペーン', '広告ID', 'KWD','sai_flg']]
shokikosho = rzshokikosho.sort_values(by='kosho_setteibi')

# %%
shokikosho.columns
# Out:
# Index(['tenki_id', '登録日時', 'kosho_setteibi', 'kosho_jisshibi', '参照元/メディア',
#        'キャンペーン', '広告ID', 'KWD', 'sai_flg'],
#       dtype='object')

# %%
shokikosho
# Out:
#       tenki_id        登録日時 kosho_setteibi kosho_jisshibi             参照元/メディア  \
# 0        44305         NaN     2019-09-30     2019-10-01                  NaN
# 18       44489         NaN     2019-09-30     2019-10-01                  NaN
# 17       45259         NaN     2019-09-30     2019-10-02                  NaN
# 16       45920         NaN     2019-09-30     2019-10-02                  NaN
# 15       45344         NaN     2019-09-30     2019-10-02                  NaN
# ...        ...         ...            ...            ...                  ...
# 38979     <NA>         NaN     2026-07-22            NaT                  NaN
# 38978     <NA>         NaN     2026-07-22            NaT                  NaN
# 38996   140733         NaN     2026-07-22            NaT                  NaN
# 38986   140703  2026/07/19     2026-07-22            NaT      yahoo / display
# 38997    97888  2022/07/17     2026-07-23            NaT  zeals_ad / chat_cpf
#
# ...

# %%
shokikosho["tenki_id"] = shokikosho["tenki_id"].str.replace('<NA>', '')
shokikosho["登録日時"] = shokikosho["登録日時"].str.replace('NaN', '')
shokikosho["kosho_setteibi"] = shokikosho["kosho_setteibi"].astype(str).str.replace('None', '')
shokikosho["kosho_jisshibi"] = shokikosho["kosho_jisshibi"].astype(str).str.replace('None', '')
shokikosho["参照元/メディア"] = shokikosho["参照元/メディア"].str.replace('NaN', '')
shokikosho["キャンペーン"] = shokikosho["キャンペーン"].str.replace('NaN', '')
shokikosho["広告ID"] = shokikosho["広告ID"].str.replace('NaN', '')
shokikosho["KWD"] = shokikosho["KWD"].str.replace('NaN', '')

# %%
shokikosho.replace([np.inf, -np.inf], np.nan, inplace=True)
shokikosho.fillna('', inplace=True)
shokikosho = shokikosho.values.tolist()

# %%
shokikosho
# Out:
# [['44305', '', '2019-09-30', '2019-10-01', '', '', '', '', 1],
#  ['44489', '', '2019-09-30', '2019-10-01', '', '', '', '', 1],
#  ['45259', '', '2019-09-30', '2019-10-02', '', '', '', '', 1],
#  ['45920', '', '2019-09-30', '2019-10-02', '', '', '', '', 1],
#  ['45344', '', '2019-09-30', '2019-10-02', '', '', '', '', 1],
#  ['45929', '', '2019-09-30', '2019-10-02', '', '', '', '', 1],
#  ['45978', '', '2019-09-30', '2019-10-09', '', '', '', '', 1],
#  ['46052', '', '2019-09-30', '2019-10-09', '', '', '', '', 1],
#  ['45966', '', '2019-09-30', '2019-10-21', '', '', '', '', 1],
#  ['45019', '', '2019-09-30', '2019-10-07', '', '', '', '', 1],
#  ['45369', '', '2019-09-30', '2019-10-10', '', '', '', '', 2],
#  ['46110', '', '2019-09-30', '2019-10-07', '', '', '', '', 1],
#  ['46151', '', '2019-09-30', '2019-10-11', '', '', '', '', 1],
#  ['46191', '', '2019-09-30', '2019-10-02', '', '', '', '', 1],
#  ['46144',
#   '2019/09/28',
#   '2019-09-30',
#   '2019-10-02',
#   'google / cpc',
# ...

# %%
#シートにコピペ
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID = '1Mvqe8nLhdiT9acCMA4cP-4MH5X4GmYPiC9OSqHTEHtk'
Sheet_NAME = 'rzdata!A'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,shokikosho,service)

# %%
# #NMのシートにコピペ
# service = ps.get_auth(SCOPES,json_path)
# SPREADSHEET_ID = '1d1uYQMCIhJGMlUe4S8m56Bd_ZS4_V-FUEtPjUlgpn9Y'
# Sheet_NAME = 'rzdata!A'
# Sheet_row = "3"
# RANGE_NAME = Sheet_NAME+Sheet_row
# ps.update_ss(SPREADSHEET_ID,RANGE_NAME,shokikosho,service)

# %%
#ZEALSのシートにコピペ
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID = '1EglGY_Lf1kvHqZTpow4F2ksD20xD9J8G1oaMIjtyj78'
Sheet_NAME = 'rzdata!A'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,shokikosho,service)

# %%
#CAのシートにコピペ
SPREADSHEET_ID = '1fVbpOYwIRsbW69EDsbJlTJwJVPTexi8RoMd3ahiO-IA'
Sheet_NAME = 'data!A'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,shokikosho,service)

# %% [markdown]
# ## 本交渉情報取得

# %%
adinfoB
# Out:
#       tenki_id        登録日時   フリ先       手上げ日付  本手上げ       KN共有日  \
# 1         1070  2016/09/17  ロンザン  2020/05/20  ZOOM
# 2         2748  2017/02/06  ロンザン  2017/02/06
# 3         7024  2017/08/07  ロンザン  2017/08/07
# 4         8539  2017/09/15  レイノス  2017/09/15
# 5         9502  2017/10/05  レイノス  2017/10/05     0
# ...        ...         ...   ...         ...   ...         ...
# 85875   140722  2026/07/20  ロンザン  2026/07/21  TRUE  2026/07/21
# 85876   140723  2026/07/21  ロンザン  2026/07/21  TRUE  2026/07/21
# 85877   140724  2026/07/21
# 85878   140725  2026/07/21  ロンザン  2026/07/21  TRUE  2026/07/21
# 85879   140726  2026/07/21  ロンザン  2026/07/21  TRUE  2026/07/21
#
#                      参照元/メディア     キャンペーン       広告ID        KWD          年齢  \
# 1                                                                       49
# 2                                                                       59
# 3         google_SHIMEI / cpc  (not set)  (not set)  (not set)          55
# ...

# %%
rzhonkosho_query = """
with HONS as (
with SHOKIS as (
with shoki_base3 as (
with shoki_base2 as (
with shoki_base as (
SELECT
  shk.id,
  shk.tenki_id,
  shk.kohosha_id,
  shk.ap_source,
  layer.name as layer,
  shk.annual_income,
  CASE WHEN syi1.sei_plus IS NULL THEN shk.mendan_tanto
       ELSE syi1.sei_plus END AS mendan_tanto,
  syi2.sei_plus AS ap_kakutokusha,
  shk.kosho_setteibi,
  shk.kosho_yoteibi,
  shk.kosho_jisshibi,
  shk.kosho_seq,
  shk.saikosho_kaisu,
  saikosho_seq,
  valid_flag,
  shk.initial_contact_date,
  DATE_DIFF(shk.kosho_setteibi, LAG(shk.kosho_jisshibi) OVER (PARTITION BY shk.kohosha_id ORDER BY shk.kosho_jisshibi), DAY) AS keikabi
FROM (
  SELECT *,
    FIRST_VALUE(kosho_jisshibi IGNORE NULLS) OVER (PARTITION BY kohosha_id ORDER BY kosho_jisshibi) AS initial_contact_date
  FROM `r-group-bigdata.live_rhs.shokikoshos`
) shk
LEFT JOIN `r-group-bigdata.live_rhs.kohoshas` koho ON shk.kohosha_id = koho.id
LEFT JOIN `r-group-bigdata.live_company.syain` syi1 ON shk.mendan_tanto = syi1.user_id
LEFT JOIN `r-group-bigdata.live_company.syain` syi2 ON shk.ap_kakutoku = syi2.user_id
LEFT JOIN (SELECT 
    code,
    name
  FROM `r-group-bigdata.live_rhs.sys_consts`
  WHERE group_code = 19) consts ON shk.ap_source = consts.code
left join (SELECT 
            group_code,
             code,
             name
            FROM `r-group-bigdata.live_rhs.sys_consts`
            where group_code = 25) layer on shk.max_bushoyakushoku = layer.code
ORDER BY shk.kosho_setteibi
)

  select *,
    LAG(ap_source) OVER (PARTITION BY kohosha_id ORDER BY kosho_setteibi) AS prev_APsource,
  from shoki_base)

  select *,
   CASE WHEN ap_source != prev_APsource THEN 1 ELSE 0
        END AS APS_change
  from shoki_base2)

  select *,
  case when kosho_seq = 1 then 1
        when APS_change = 1 then 1
        when keikabi > 90 then 2
        else 0 end as sai_flg
  from shoki_base3
  order by kosho_setteibi desc
)

SELECT 
  hon.id as honkosho_id,
  hon.anken_id as anken_id,
  an.kohosha_id as kohosha_id,
  koho.tenki_id,
  an.linked_shokikosho_id,
  kgy.tsr_code as tsr_code,
  kgy.name,
  case when consts.name is null then consts2.name
       else consts.name end as AP_source,
  shoki.annual_income,
  shoki.layer,
  initial_contact_date,
  format_date('%Y/%m/%d',shoki.kosho_setteibi) as shoki_setteibi,
  format_date('%Y/%m/%d',shoki.kosho_jisshibi) as shoki_jisshibi,
  format_date('%Y/%m/%d',hon.kosho_setteibi) as hon_setteibi,
  format_date('%Y/%m/%d',hon.kosho_yoteibi) as hon_yoteibi,
  format_date('%Y/%m/%d',hon.kosho_jisshibi) as hon_jisshibi,
  case when syi1.sei_plus is null then hon.kohosha_tanto
  else syi1.sei_plus end as kohosha_tanto,
  syi2.sei_plus as kigyo_tanto,
  hon.kosho_seq as hon_seq,
  shoki.kosho_seq,
  shoki.sai_flg,
  DATE_DIFF(hon.kosho_setteibi, shoki.kosho_jisshibi, DAY) as jisshibi_sa,
  yomi.name as yomi,
  case when yomi2.name is null then yomi.name
       when yomi2.name = yomi.name then yomi2.name
       else yomi2.name end as yomi_final,
  ROUND(tokikessan_uriagedaka/100000,0)as URIAGE,
  consts3.name as yakushoku_class,
  first_mendan.mendan_tanto as first_mendan_tanto
FROM `r-group-bigdata.live_rhs.honkoshos` hon
LEFT JOIN `r-group-bigdata.live_rhs.ankens` an on hon.anken_id = an.id
left join (with yomis_base as (
           SELECT *,
           row_number() over (partition by anken_id order by yomi_torokubi desc) as rn
           FROM `r-group-bigdata.live_rhs.honkosho_yomis`)
           select *
          from yomis_base
          where rn = 1) yomis on an.id = yomis.anken_id
LEFT JOIN SHOKIS shoki on an.linked_shokikosho_id = shoki.id
LEFT JOIN `r-group-bigdata.live_rhs.kigyos` kgy on an.kigyo_id = kgy.id
left join `r-group-bigdata.tsr.company_info` tsr on kgy.tsr_code = tsr.tsr_code
LEFT JOIN `r-group-bigdata.live_rhs.kohoshas` koho on an.kohosha_id = koho.id
LEFT JOIN `r-group-bigdata.live_company.syain` syi1 on hon.kohosha_tanto = syi1.user_id
LEFT JOIN `r-group-bigdata.live_company.syain` syi2 on an.kigyo_tanto = syi2.user_id
left join (select
              shoki.id,
              shoki.kohosha_id,
              case when syi3.sei_plus is null then shoki.mendan_tanto
                   else syi3.sei_plus end as mendan_tanto,
              shoki.kosho_jisshibi
             from `r-group-bigdata.live_rhs.shokikoshos` shoki 
             left join `r-group-bigdata.live_company.syain` syi3 on shoki.mendan_tanto = syi3.user_id
             where kosho_seq = 1) first_mendan on an.kohosha_id = first_mendan.kohosha_id
LEFT JOIN (SELECT code,name
             FROM `r-group-bigdata.live_rhs.sys_consts`
             where group_code = 19) consts on shoki.ap_source = consts.code
LEFT JOIN (SELECT code,name
             FROM `r-group-bigdata.live_rhs.sys_consts`
             where group_code = 19) consts2 on koho.ap_source = consts2.code
left join (SELECT code,name
             FROM `r-group-bigdata.live_rhs.sys_consts`
             where group_code = 9) yomi on hon.yomi = yomi.code
left join (SELECT code,name
             FROM `r-group-bigdata.live_rhs.sys_consts`
             where group_code = 9) yomi2 on yomis.yomi = yomi2.code
left join (SELECT code,name
             FROM `r-group-bigdata.live_rhs.sys_consts`
             where group_code = 10) consts3 on hon.yakushoku_class = consts3.code
-- where hon.kosho_seq = 1
)

select *,
  case when AP_source = '転機社長名鑑' then '転機'
       when AP_source = '人事部経由' then '人事部紹介'
       when AP_source = '顧問名鑑登録　解放者' then '顧問名鑑登録者'
       when AP_source = 'HP反響' then 'その他'
       when AP_source = '上場企業役員DM' then 'その他'
       when AP_source = '社外取締役名鑑　候補者' then '顧問名鑑登録者'
       when AP_source = 'Gアポ' then 'その他'
       else AP_source end as APsource,

  case when shoki_jisshibi is null then 2
       when jisshibi_sa > 90 then 2
       else sai_flg end as sai_flg2 
from HONS
where AP_source = "転機社長名鑑"
-- and hon_setteibi >= "2025/03/27"
order by anken_id
"""
client = bigquery.Client(credentials=credentials, project=credentials.project_id)
honkosho = client.query(rzhonkosho_query).result().to_dataframe()

# %%
honkosho["tenki_id"] = honkosho["tenki_id"].astype(str)
honkosho = pd.merge(honkosho,adinfoB,how="left", on="tenki_id")

# %%
honkosho = honkosho[["tenki_id","登録日時","hon_setteibi","hon_jisshibi","参照元/メディア","キャンペーン","広告ID","KWD","sai_flg2"]]

# %%
honkosho["tenki_id"] = honkosho["tenki_id"].str.replace('<NA>', '')
honkosho["登録日時"] = honkosho["登録日時"].str.replace('NaN', '')
honkosho["hon_jisshibi"] = honkosho["hon_jisshibi"].str.replace('None', '')
honkosho["参照元/メディア"] = honkosho["参照元/メディア"].str.replace('NaN', '')
honkosho["キャンペーン"] = honkosho["キャンペーン"].str.replace('NaN', '')
honkosho["広告ID"] = honkosho["広告ID"].str.replace('NaN', '')
honkosho["KWD"] = honkosho["KWD"].str.replace('NaN', '')

# %%
honkosho.dtypes
# Out:
# tenki_id        object
# 登録日時            object
# hon_setteibi    object
# hon_jisshibi    object
# 参照元/メディア        object
# キャンペーン          object
# 広告ID            object
# KWD             object
# sai_flg2         Int64
# dtype: object

# %%
honkosho.replace([np.inf, -np.inf], np.nan, inplace=True)
honkosho.fillna('', inplace=True)
honkosho = honkosho.values.tolist()

# %%
#成約単価シートにコピペ
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID = '1Mvqe8nLhdiT9acCMA4cP-4MH5X4GmYPiC9OSqHTEHtk'
Sheet_NAME = 'rzdata!J'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,honkosho,service)

# %%
#NMのシートにコピペ
SPREADSHEET_ID = '1d1uYQMCIhJGMlUe4S8m56Bd_ZS4_V-FUEtPjUlgpn9Y'
Sheet_NAME = 'rzdata!J'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,honkosho,service)

# %%
#ZEALSのシートにコピペ
SPREADSHEET_ID = '1EglGY_Lf1kvHqZTpow4F2ksD20xD9J8G1oaMIjtyj78'
Sheet_NAME = 'rzdata!J'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,honkosho,service)

# %%
#CAのシートにコピペ
SPREADSHEET_ID = '1fVbpOYwIRsbW69EDsbJlTJwJVPTexi8RoMd3ahiO-IA'
Sheet_NAME = 'data!J'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,honkosho,service)

# %% [markdown]
# ## SCKPI

# %%
adinfoC = adinfo.copy()

# %%
sckpi_query = """
WITH
-- =================================================================
-- データ結合と基本加工セクション
-- 必要なテーブルを結合し、基本的なカラムを計算する
-- =================================================================
base_data AS (
  SELECT
    rc.tenki_id,
    can.ap_kakutoku AS shokikosho_setteibi,
    rc.first_nmen_date AS first_jisshi_date,
    can.nmen_zisshi AS shokikosho_jisshibi,
    -- COALESCE関数を使い、繰り返しが多いCASE文を簡潔に書き換え
    COALESCE(
      com.settei8, com.settei7, com.settei6, com.settei5,
      com.settei4, com.settei3, com.settei2, com.settei1
    ) AS honkosho_setteibi,
    COALESCE(
      com.zisshi8, com.zisshi7, com.zisshi6, com.zisshi5,
      com.zisshi4, com.zisshi3, com.zisshi2, com.zisshi1
    ) AS honkosho_jissibi,
    com.seiyaku,
    can.kouhosya_tantou AS kohosha_tanto,
    can.client_tantou AS kigyo_tanto,
    can.mendan_tantou AS mendan_tanto,
    can.ap_source,
    CASE
      WHEN can.zisshi LIKE 'キャンセル%' THEN 'CXL'
      WHEN can.zisshi LIKE '%実施%' THEN '実施'
      ELSE '-'
    END AS CXL_status
  FROM
    `r-group-bigdata.live_sugarcrm52.rc_race_candidate_management` AS rc
    LEFT JOIN `r-group-bigdata.live_saltcrm.candidate` AS can ON can.sugarid = rc.candidate_no
    LEFT JOIN `r-group-bigdata.live_saltcrm.company` AS com ON com.candidate_id = can.id
  WHERE
    rc.tenki_id IS NOT NULL
    AND rc.deleted = 0
)

-- =================================================================
-- 最終的な集計と出力
-- ウィンドウ関数を用いて登場回数をカウントする
-- =================================================================
SELECT
  *,
  -- tenki_idごとに、shokikosho_setteibi（設定日）の昇順で登場回数をカウント
  ROW_NUMBER() OVER (PARTITION BY tenki_id ORDER BY shokikosho_setteibi) AS sai_flg
FROM
  base_data
where shokikosho_setteibi >= "2019-10-01"
and (ap_source = "転機" or ap_source = "マッチング")
ORDER BY
  shokikosho_setteibi;

"""

client = bigquery.Client(credentials=credentials, project=credentials.project_id)
sckpi = client.query(sckpi_query).result().to_dataframe()

# %%
adinfoC = adinfoC.query('フリ先 == "レイノス"')
adinfoC = adinfoC[["tenki_id","登録日時","フリ先","手上げ日付","参照元/メディア","キャンペーン","広告ID","KWD"]]

# %%
adinfoC
# Out:
#       tenki_id        登録日時   フリ先       手上げ日付                   参照元/メディア  \
# 4         8539  2017/09/15  レイノス  2017/09/15            fb_ad / display
# 5         9502  2017/10/05  レイノス  2017/10/05         yahoo_Ten / cpc_CA
# 7        12216  2017/12/13  レイノス  2017/12/13           google / organic
# 8        12406  2017/12/20  レイノス  2017/12/20    google_Saiyo / cpc_Area
# 9        12511  2017/12/24  レイノス  2017/12/24      google_Saiyo / cpc_CA
# ...        ...         ...   ...         ...                        ...
# 85543   140390  2026/06/28  レイノス  2026/06/30  zeals_ad,zeals / chat_cpf
# 85708   140555  2026/07/10  レイノス  2026/07/13         facebook / display
# 85749   140596  2026/07/12  レイノス  2026/07/14     facebookcasm / display
# 85754   140601  2026/07/13  レイノス  2026/07/14
# 85787   140634  2026/07/15  レイノス  2026/07/17           google / organic
#
#             キャンペーン       広告ID             KWD
# 4        (not set)  (not set)       (not set)
# ...

# %%
sckpi = sckpi.rename(columns={"tenki_id":"ID"})
sckpi = sckpi.rename(columns={"ID":"tenki_id"})
sckpi["tenki_id"] = sckpi["tenki_id"].astype(str)
sckpi["shokikosho_setteibi"] = sckpi["shokikosho_setteibi"].astype(str)
sckpi["first_jisshi_date"] = sckpi["first_jisshi_date"].astype(str)
sckpi["shokikosho_jisshibi"] = sckpi["shokikosho_jisshibi"].astype(str)
sckpi["honkosho_setteibi"] = sckpi["honkosho_setteibi"].astype(str)
sckpi["honkosho_jissibi"] = sckpi["honkosho_jissibi"].astype(str)
sckpi["seiyaku"] = sckpi["seiyaku"].astype(str)

# %%
sckpi = pd.merge(sckpi,adinfoC,how="left",on="tenki_id")

# %%
sckpi["登録日時"] = sckpi["登録日時"].str.replace('NaN', '')
sckpi["フリ先"] = sckpi["フリ先"].str.replace('NaN', '')
sckpi["手上げ日付"] = sckpi["手上げ日付"].str.replace('NaN', '')
sckpi["参照元/メディア"] = sckpi["参照元/メディア"].str.replace('NaN', '')
sckpi["キャンペーン"] = sckpi["キャンペーン"].str.replace('NaN', '')
sckpi["広告ID"] = sckpi["広告ID"].str.replace('NaN', '')
sckpi["KWD"] = sckpi["KWD"].str.replace('NaN', '')

sckpi["first_jisshi_date"] = sckpi["first_jisshi_date"].str.replace('NaT', '')
sckpi["shokikosho_jisshibi"] = sckpi["shokikosho_jisshibi"].str.replace('NaT', '')
sckpi["honkosho_setteibi"] = sckpi["honkosho_setteibi"].str.replace('NaT', '')
sckpi["honkosho_jissibi"] = sckpi["honkosho_jissibi"].str.replace('NaT', '')
sckpi["seiyaku"] = sckpi["seiyaku"].str.replace('NaT', '')

# %%
sckpi_nm = sckpi.drop(columns=['kohosha_tanto','kigyo_tanto','mendan_tanto','CXL_status'])

# %%
sckpi
# Out:
#       tenki_id shokikosho_setteibi first_jisshi_date shokikosho_jisshibi  \
# 0        45935          2019-10-01        2019-10-10          2019-10-10
# 1        46091          2019-10-01        2019-10-31          2019-10-31
# 2        46183          2019-10-01        2019-10-10          2019-10-10
# 3        46213          2019-10-01        2019-10-07          2019-10-07
# 4        46246          2019-10-01        2019-10-07          2019-10-07
# ...        ...                 ...               ...                 ...
# 14665    47162          2026-07-22              None                None
# 14666    97217          3000-01-01              None          1970-01-01
# 14667   101893          3000-01-01              None          1970-01-01
# 14668   103020          3000-01-01              None          1970-01-01
# 14669    74725          3000-01-01        2020-12-29          1970-01-01
#
#       honkosho_setteibi honkosho_jissibi     seiyaku kohosha_tanto  \
# ...

# %%
sckpi.replace([np.inf, -np.inf], np.nan, inplace=True)
sckpi.fillna('', inplace=True)

sckpi = sckpi.values.tolist()

# %%
sckpi_nm.replace([np.inf, -np.inf], np.nan, inplace=True)
sckpi_nm.fillna('', inplace=True)

sckpi_nm = sckpi_nm.values.tolist()

# %%
##成約単価シートにコピペ
SPREADSHEET_ID = '1Mvqe8nLhdiT9acCMA4cP-4MH5X4GmYPiC9OSqHTEHtk'
Sheet_NAME = 'scdata!A'
Sheet_row = "2"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,sckpi,service)

# %%
##NMのシートにコピペ
SPREADSHEET_ID = '1d1uYQMCIhJGMlUe4S8m56Bd_ZS4_V-FUEtPjUlgpn9Y'
Sheet_NAME = 'scdata!A'
Sheet_row = "2"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,sckpi_nm,service)

# %%
#CAのシートにコピペ
SPREADSHEET_ID = '1fVbpOYwIRsbW69EDsbJlTJwJVPTexi8RoMd3ahiO-IA'
Sheet_NAME = 'scdata!A'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,sckpi_nm,service)

# %% [markdown]
# ## 成約データ

# %%
# 最後のIDを取得する
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID = '1qtTngN03WSZ_JjZovhNVh6bd1uc_Eh8tRP5Hp9yWSNc'
Sheet_NAME = 'yomihyo!A'
Sheet_row = ":T"
RANGE_NAME = Sheet_NAME+Sheet_row

seiyaku = ps.get_ss(SPREADSHEET_ID,RANGE_NAME,service)

# データ取得処理の呼び出し
# seiyaku = fetch_spreadsheet(service, SPREADSHEET_ID, RANGE_NAME)

# %%
adinfoB
# Out:
#       tenki_id        登録日時   フリ先       手上げ日付  本手上げ       KN共有日  \
# 1         1070  2016/09/17  ロンザン  2020/05/20  ZOOM
# 2         2748  2017/02/06  ロンザン  2017/02/06
# 3         7024  2017/08/07  ロンザン  2017/08/07
# 4         8539  2017/09/15  レイノス  2017/09/15
# 5         9502  2017/10/05  レイノス  2017/10/05     0
# ...        ...         ...   ...         ...   ...         ...
# 85875   140722  2026/07/20  ロンザン  2026/07/21  TRUE  2026/07/21
# 85876   140723  2026/07/21  ロンザン  2026/07/21  TRUE  2026/07/21
# 85877   140724  2026/07/21
# 85878   140725  2026/07/21  ロンザン  2026/07/21  TRUE  2026/07/21
# 85879   140726  2026/07/21  ロンザン  2026/07/21  TRUE  2026/07/21
#
#                      参照元/メディア     キャンペーン       広告ID        KWD          年齢  \
# 1                                                                       49
# 2                                                                       59
# 3         google_SHIMEI / cpc  (not set)  (not set)  (not set)          55
# ...

# %%
seiyaku
# Out:
#         転機ID   案件ID         登録日    部署                 計上日                      \
# 1          -   1736           -  ロンザン  2017-10-17 0:00:00  2017-10-17 0:00:00
# 2       8871   1815           -  ロンザン  2017-10-31 0:00:00  2017-10-31 0:00:00
# 3          -   1546           -  ロンザン  2017-11-13 0:00:00  2017-11-13 0:00:00
# 4          -   1817           -  ロンザン  2017-11-21 0:00:00  2017-11-21 0:00:00
# 5          -   1865           -  ロンザン  2017-11-27 0:00:00  2017-11-27 0:00:00
# ...      ...    ...         ...   ...                 ...                 ...
# 1478  137293  29798  2025/12/14  ロンザン  2026-06-30 0:00:00                   -
# 1479       -  29334           -  ロンザン  2026-06-30 0:00:00                   -
# 1480  139777  29409  2026/05/11  ロンザン  2026-06-30 0:00:00                   -
# 1481  138122  28546  2026/02/11  ロンザン  2026-07-14 0:00:00  2026-04-28 0:00:00
# 1482  122881  28587  2024/10/30  ロンザン  2026-07-22 0:00:00  2026-07-06 0:00:00
#
# ...

# %%
adinfoB = adinfoB.rename(columns={"tenki_id":"転機ID"})

seiyaku = pd.merge(seiyaku,adinfoB,how="left", on="転機ID")

# %%
seiyaku["移籍年収"] = ""
seiyaku = seiyaku[["転機ID","登録日","計上日","獲得P","参照元/メディア","キャンペーン","広告ID","KWD","前職年収","移籍年収","売上金額","sai_flg"]]

# %%
seiyaku
# Out:
#         転機ID         登録日                 計上日        獲得P  \
# 0          -           -  2017-10-17 0:00:00   60.01086
# 1       8871           -  2017-10-31 0:00:00   79.21872
# 2          -           -  2017-11-13 0:00:00  50.252244
# 3          -           -  2017-11-21 0:00:00  141.76302
# 4          -           -  2017-11-27 0:00:00      45.36
# ...      ...         ...                 ...        ...
# 1477  137293  2025/12/14  2026-06-30 0:00:00    202.041
# 1478       -           -  2026-06-30 0:00:00     69.194
# 1479  139777  2026/05/11  2026-06-30 0:00:00    203.233
# 1480  138122  2026/02/11  2026-07-14 0:00:00    175.248
# 1481  122881  2024/10/30  2026-07-22 0:00:00    160.963
#
#                        参照元/メディア      キャンペーン       広告ID        KWD  前職年収 移籍年収  \
# 0                           NaN         NaN        NaN        NaN  1200
# 1                           NaN         NaN        NaN        NaN  2040
# ...

# %%
seiyaku["参照元/メディア"] = seiyaku["参照元/メディア"].str.replace('NaN', '')
seiyaku["キャンペーン"] = seiyaku["キャンペーン"].str.replace('NaN', '')
seiyaku["広告ID"] = seiyaku["広告ID"].str.replace('NaN', '')
seiyaku["KWD"] = seiyaku["KWD"].str.replace('NaN', '')
seiyaku["売上金額"] = seiyaku["売上金額"].str.replace('NaN', '')

# %%
seiyaku
# Out:
#         転機ID         登録日                 計上日        獲得P  \
# 0          -           -  2017-10-17 0:00:00   60.01086
# 1       8871           -  2017-10-31 0:00:00   79.21872
# 2          -           -  2017-11-13 0:00:00  50.252244
# 3          -           -  2017-11-21 0:00:00  141.76302
# 4          -           -  2017-11-27 0:00:00      45.36
# ...      ...         ...                 ...        ...
# 1477  137293  2025/12/14  2026-06-30 0:00:00    202.041
# 1478       -           -  2026-06-30 0:00:00     69.194
# 1479  139777  2026/05/11  2026-06-30 0:00:00    203.233
# 1480  138122  2026/02/11  2026-07-14 0:00:00    175.248
# 1481  122881  2024/10/30  2026-07-22 0:00:00    160.963
#
#                        参照元/メディア      キャンペーン       広告ID        KWD  前職年収 移籍年収  \
# 0                           NaN         NaN        NaN        NaN  1200
# 1                           NaN         NaN        NaN        NaN  2040
# ...

# %%
seiyaku_tk = seiyaku.copy()
seiyaku_tk.replace([np.inf, -np.inf], np.nan, inplace=True)
seiyaku_tk.fillna('', inplace=True)
seiyaku_tk = seiyaku_tk.values.tolist()

# %%
##成約単価シートにコピペ
SPREADSHEET_ID = '1Mvqe8nLhdiT9acCMA4cP-4MH5X4GmYPiC9OSqHTEHtk'
Sheet_NAME = 'rzdata!S'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,seiyaku_tk,service)

# %%
#NMのシートにコピペ
SPREADSHEET_ID = '1d1uYQMCIhJGMlUe4S8m56Bd_ZS4_V-FUEtPjUlgpn9Y'
Sheet_NAME = 'rzdata!S'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,seiyaku_tk,service)

# %%
#ZEALSのシートにコピペ
SPREADSHEET_ID = '1EglGY_Lf1kvHqZTpow4F2ksD20xD9J8G1oaMIjtyj78'
Sheet_NAME = 'rzdata!S'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,seiyaku_tk,service)

# %%
#CAのシートにコピペ
SPREADSHEET_ID = '1fVbpOYwIRsbW69EDsbJlTJwJVPTexi8RoMd3ahiO-IA'
Sheet_NAME = 'data!S'
Sheet_row = "3"
RANGE_NAME = Sheet_NAME+Sheet_row
ps.update_ss(SPREADSHEET_ID,RANGE_NAME,seiyaku_tk,service)

# %% [markdown]
# ### CR別パフォーマンスを更新

# %%
#当月の初日を取得
now = datetime.datetime.now()
def get_first_date(year,month):
    return datetime.date(year, month, 1)
firstday = get_first_date(now.year,now.month)
firstday_minus_60 = firstday - datetime.timedelta(days=30)
firstday_minus_60 = firstday_minus_60.strftime("%Y-%m-%d")
firstday_minus_60
# Out:
# '2026-06-01'

# %% [markdown]
# ## 広告情報取得

# %%
#最後のIDを取得する
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID = '14vXxjcdlyY463QjrtEnCw7pJ0oLStXZD8Q42IdW2Zd4'
Sheet_NAME = '候補者マスタ!A'
Sheet_row = ":M"
RANGE_NAME = Sheet_NAME+Sheet_row
adinfo = ps.get_ss(SPREADSHEET_ID,RANGE_NAME,service)

# %%
adinfoA = adinfo.copy()

# %%
adinfoA.dtypes
# Out:
# tenki_id    object
# 登録日時        object
# フリ先         object
# 手上げ日付       object
# 本手上げ        object
# KN共有日       object
# 参照元/メディア    object
# キャンペーン      object
# 広告ID        object
# KWD         object
#             object
# 年齢          object
# 役職          object
# dtype: object

# %%
#IDのデータ型をint64に変換
adinfoA['tenki_id'] = pd.to_numeric(adinfoA['tenki_id'], errors='coerce')
adinfoA['tenki_id'] = adinfoA['tenki_id'].fillna(0)
adinfoA['tenki_id'] = adinfoA['tenki_id'].astype('int64')

# `登録日時`列が文字列型（str）の場合、以下のコードでdatetime形式に変換します
adinfoA['登録日時'] = pd.to_datetime(adinfoA['登録日時'])

# 特定の日付以降のデータのみを抽出します
adinfoA = adinfoA[adinfoA['登録日時'] >= firstday_minus_60]

# 'フリ先'が'ロンザン'または'レイノス'と一致する場合、'1'に変換
adinfoA.loc[adinfoA['フリ先'].isin(['ロンザン', 'レイノス']), 'フリ先'] = '1'

# 'フリ先'が'送信NG'と一致する場合、空白に変換
adinfoA.loc[adinfoA['フリ先'] == '送信NG', 'フリ先'] = ''

# '本手上げ'が'TRUE'なら'1'、'FALSE'なら'0'に変換
adinfoA.loc[adinfoA['本手上げ'] == 'TRUE', '本手上げ'] = '1'
adinfoA.loc[adinfoA['本手上げ'] == 'FALSE', '本手上げ'] = '0'

# %%
adinfoA
# Out:
#        tenki_id       登録日時 フリ先       手上げ日付 本手上げ       KN共有日  \
# 85185    140032 2026-06-01   1  2026/06/01    1
# 85186    140033 2026-06-01   1  2026/06/02    1  2026/06/02
# 85187    140034 2026-06-01
# 85188    140035 2026-06-01   1  2026/06/02    1
# 85189    140036 2026-06-01   1  2026/06/02    1  2026/06/02
# ...         ...        ...  ..         ...  ...         ...
# 85875    140722 2026-07-20   1  2026/07/21    1  2026/07/21
# 85876    140723 2026-07-21   1  2026/07/21    1  2026/07/21
# 85877    140724 2026-07-21
# 85878    140725 2026-07-21   1  2026/07/21    1  2026/07/21
# 85879    140726 2026-07-21   1  2026/07/21    1  2026/07/21
#
#                      参照元/メディア            キャンペーン       広告ID        KWD  \
# 85185        google / organic         (organic)  (not set)  (not set)
# 85186  facebookcasm / display              CP02      ADS09  (not set)
# 85187          bing / organic         (organic)  (not set)  (not set)
# ...

# %% [markdown]
# ## 登録情報取得

# %%
# クエリの一例です。ご自身の実行したいクエリに書き換えて下さい。
tkuserinfo_query = f"""
select
	inf.id,
	format_date('%Y/%m/%d',inf.created_at) as created_at,
	concat(trim(replace(inf.shi,'　',' ')),trim(replace(inf.mei,'　',' '))) as name,
	inf.seibetu,
  concat(inf.birth_year,"/",inf.birth_month,"/",inf.birth_day) as birthday,
  extract(year from inf.created_at)-inf.birth_year as age,
	inf.email,
	inf.mob_tel,
	inf.comp_name,
	inf.gyousyu1,
	inf.jobcat,
	inf.syokusyu1,
	inf.layer,
	inf.income,
  inf.management_num1,
	inf.change_job,
	concat(corp_from_year1,"/",corp_from_month1,"~",
	       ifnull(cast(corp_to_year1 as string),""),"/",ifnull(cast(corp_to_month1 as string),"")) as zaiseki_kikan,
  inf.pref,
	inf.work_pref,
	inf.wish_pref,
	inf.moving,
	inf.kanou_jiki,
	format_date('%Y/%m/%d',dt.keireki_ja_date) as shokureki_upload_date
from
	`r-group-bigdata.live_tenki.user_info` inf
left join `r-group-bigdata.live_tenki.user_detail` dt on inf.id = dt.id 
where
    created_at >= date '{firstday_minus_60}'
order by id
"""
client = bigquery.Client(credentials=credentials, project=credentials.project_id)
tkuserinfo = client.query(tkuserinfo_query).result().to_dataframe()
tkuserinfo = tkuserinfo.rename(columns={"id":"ID"})

# %%
adinfoA.columns
# Out:
# Index(['tenki_id', '登録日時', 'フリ先', '手上げ日付', '本手上げ', 'KN共有日', '参照元/メディア',
#        'キャンペーン', '広告ID', 'KWD', '', '年齢', '役職'],
#       dtype='object')

# %%
adinfoA = adinfoA.rename(columns={"tenki_id":"ID"})
ALL_data = pd.merge(adinfoA,tkuserinfo,how='left',on='ID')
ALL_data = ALL_data[["ID","登録日時","フリ先","手上げ日付","本手上げ","参照元/メディア","キャンペーン",
                     "広告ID","KWD","年齢","income","役職","pref","gyousyu1","jobcat","syokusyu1","change_job"]]

# %%
ALL_data
# Out:
#          ID       登録日時 フリ先       手上げ日付 本手上げ                参照元/メディア  \
# 0    140032 2026-06-01   1  2026/06/01    1        google / organic
# 1    140033 2026-06-01   1  2026/06/02    1  facebookcasm / display
# 2    140034 2026-06-01                               bing / organic
# 3    140035 2026-06-01   1  2026/06/02    1      yahoo / paidsearch
# 4    140036 2026-06-01   1  2026/06/02    1
# ..      ...        ...  ..         ...  ...                     ...
# 690  140722 2026-07-20   1  2026/07/21    1  facebookcasm / display
# 691  140723 2026-07-21   1  2026/07/21    1               (not set)
# 692  140724 2026-07-21                                    (not set)
# 693  140725 2026-07-21   1  2026/07/21    1               (not set)
# 694  140726 2026-07-21   1  2026/07/21    1               (not set)
#
#                キャンペーン       広告ID        KWD  年齢       income     役職  pref  \
# 0           (organic)  (not set)  (not set)  43  2000～2999万円  役員クラス   東京都
# ...

# %% [markdown]
# ## 各種シートに貼り付け

# %%
#NMシートを取得
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID_NM = '1YRjsfJ76yfAnhoyTlsvcXVKZhmmcvkNwpApf9iubByc'
Sheet_NAME = 'サマリー!A'
Sheet_row = ":A"
RANGE_NAME = Sheet_NAME+Sheet_row
recentID_NM = ps.get_ss(SPREADSHEET_ID_NM,RANGE_NAME,service)

#CAシートを取得
SPREADSHEET_ID_CA = '1fVbpOYwIRsbW69EDsbJlTJwJVPTexi8RoMd3ahiO-IA'
Sheet_NAME = 'サマリー!A'
Sheet_row = ":A"
RANGE_NAME = Sheet_NAME+Sheet_row
recentID_CA = ps.get_ss(SPREADSHEET_ID_CA,RANGE_NAME,service)

#GAXシートを取得
SPREADSHEET_ID_GAX = '1JxBS0dT8nR_o_ehqVdlKYx3iD1jEMIaQPXWl6wJIXJk'
Sheet_NAME = '手上げデータ!A'
Sheet_row = ":A"
RANGE_NAME = Sheet_NAME+Sheet_row
recentID_GAX = ps.get_ss(SPREADSHEET_ID_GAX,RANGE_NAME,service)

# %%
#データを入力するセルを特定
recentID_NM['転機ID'] =recentID_NM['転機ID'].astype('int64')
recentID_CA['ID'] =recentID_CA['ID'].astype('int64')
recentID_GAX['ID'] =recentID_GAX['ID'].astype('int64')
matching_index_NM = recentID_NM[recentID_NM["転機ID"] == ALL_data['ID'][0]].index
matching_index_CA = recentID_CA[recentID_CA["ID"] == ALL_data['ID'][0]].index
matching_index_GAX = recentID_GAX[recentID_GAX["ID"] == ALL_data['ID'][0]].index

# %%
matching_index_NM
# Out:
# Index([], dtype='int64')

# %%
# matching_index_NM の中身が1つ以上あるか確認します
if len(matching_index_NM) > 0:
    print(matching_index_NM[0] + 1)
else:
    print("NM: 条件に一致するデータが見つかりませんでした。")

# matching_index_CA の確認
if len(matching_index_CA) > 0:
    print(matching_index_CA[0] + 1)
else:
    print("CA: 条件に一致するデータが見つかりませんでした。")

# matching_index_GAX の確認
if len(matching_index_GAX) > 0:
    print(matching_index_GAX[0] + 1)
else:
    print("GAX: 条件に一致するデータが見つかりませんでした。")
# Out:
# NM: 条件に一致するデータが見つかりませんでした。
# CA: 条件に一致するデータが見つかりませんでした。
# GAX: 条件に一致するデータが見つかりませんでした。

# %%
ALL_data["ID"] = ALL_data["ID"].astype(str) 
ALL_data["登録日時"] = ALL_data["登録日時"].astype(str)

# infをNaNに置き換え
ALL_data.replace([np.inf, -np.inf], np.nan, inplace=True)

# NaNをNoneに置き換え
ALL_data = ALL_data.where(pd.notnull(ALL_data), None)


ALL_data = ALL_data.values.tolist()

# %%
ALL_data
# Out:
# [['140032',
#   '2026-06-01',
#   '1',
#   '2026/06/01',
#   '1',
#   'google / organic',
#   '(organic)',
#   '(not set)',
#   '(not set)',
#   '43',
#   '2000～2999万円',
#   '役員クラス',
#   '東京都',
#   '小売・流通',
#   '経営(役員・CxO）/経営企画',
#   '経営者・CEO・COO等',
#   '4回（5社経験）'],
#  ['140033',
#   '2026-06-01',
#   '1',
#   '2026/06/02',
#   '1',
#   'facebookcasm / display',
#   'CP02',
#   'ADS09',
#   '(not set)',
#   '59',
#   '800～899万円',
#   '課長クラス',
#   '愛知県',
#   '自動車',
#   '管理部門',
#   '内部監査',
#   '4回（5社経験）'],
#  ['140034',
#   '2026-06-01',
#   '',
#   '',
#   '',
#   'bing / organic',
#   '(organic)',
#   '(not set)',
#   '(not set)',
#   '60',
#   '400～499万円',
#   '課長クラス',
#   '東京都',
#   'その他',
#   '専門職（士業）',
#   'その他専門職',
#   '転職経験なし'],
#  ['140035',
#   '2026-06-01',
#   '1',
#   '2026/06/02',
#   '1',
#   'yahoo / paidsearch',
#   'y01_brand_single',
#   '1361',
#   '(not set)',
#   '55',
#   '1200～1299万円',
#   '役員クラス',
#   '東京都',
#   '外食',
#   '経営(役員・CxO）/経営企画',
#   '新規事業企画',
# ...

# %%
# 認証の準備
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES, json_path)


# NMシートへの書き込み処理
if len(matching_index_NM) > 0:
    SPREADSHEET_ID_NM = '1YRjsfJ76yfAnhoyTlsvcXVKZhmmcvkNwpApf9iubByc'
    Sheet_NAME = 'サマリー!A'
    Sheet_row = str(matching_index_NM[0] + 1)
    RANGE_NAME = Sheet_NAME + Sheet_row
    ps.update_ss(SPREADSHEET_ID_NM, RANGE_NAME, ALL_data, service)
    print("NMシートの更新が完了しました。")
else:
    print("スキップ: NMの条件に一致するデータが見つかりませんでした。")


# CAシートへの書き込み処理
if len(matching_index_CA) > 0:
    SPREADSHEET_ID_CA = '1fVbpOYwIRsbW69EDsbJlTJwJVPTexi8RoMd3ahiO-IA'
    Sheet_NAME = 'サマリー!A'
    Sheet_row = str(matching_index_CA[0] + 1)
    RANGE_NAME = Sheet_NAME + Sheet_row
    ps.update_ss(SPREADSHEET_ID_CA, RANGE_NAME, ALL_data, service)
    print("CAシートの更新が完了しました。")
else:
    print("スキップ: CAの条件に一致するデータが見つかりませんでした。")


# GAXシートへの書き込み処理
if len(matching_index_GAX) > 0:
    SPREADSHEET_ID_GAX = '1JxBS0dT8nR_o_ehqVdlKYx3iD1jEMIaQPXWl6wJIXJk'
    Sheet_NAME = '手上げデータ!A'
    Sheet_row = str(matching_index_GAX[0] + 1)
    RANGE_NAME = Sheet_NAME + Sheet_row
    ps.update_ss(SPREADSHEET_ID_GAX, RANGE_NAME, ALL_data, service)
    print("GAXシートの更新が完了しました。")
else:
    print("スキップ: GAXの条件に一致するデータが見つかりませんでした。")
# Out:
# スキップ: NMの条件に一致するデータが見つかりませんでした。
# スキップ: CAの条件に一致するデータが見つかりませんでした。
# スキップ: GAXの条件に一致するデータが見つかりませんでした。

# %% [markdown]
# ## 媒体の広告を抽出する

# %%
adinfo.columns
# Out:
# Index(['tenki_id', '登録日時', 'フリ先', '手上げ日付', '本手上げ', 'KN共有日', '参照元/メディア',
#        'キャンペーン', '広告ID', 'KWD', '', '年齢', '役職'],
#       dtype='object')

# %%
adinfoB = adinfo.copy()
adinfoB = adinfoB[["tenki_id","登録日時","キャンペーン","広告ID"]]
adinfoB = adinfoB[adinfoB["キャンペーン"] == "nm_facebook"] 
adinfoB['登録日時'] = pd.to_datetime(adinfoB['登録日時'])
adinfoB = adinfoB[adinfoB['登録日時'] >= firstday_minus_60]
adinfoB['tenki_id'] = adinfoB['tenki_id'].astype('int64')

# %%
# データが1件以上あるか確認してから最初のIDを取り出す
if len(adinfoB) > 0:
    first_tenki_id = adinfoB['tenki_id'].iloc[0]
    print(first_tenki_id)
else:
    print("条件（キャンペーンや日付）に一致するデータが見つかりませんでした。")
# Out:
# 条件（キャンペーンや日付）に一致するデータが見つかりませんでした。

# %%
#NMシートを取得
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
          'https://www.googleapis.com/auth/spreadsheets']
json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
service = ps.get_auth(SCOPES,json_path)
SPREADSHEET_ID_NM = '1YRjsfJ76yfAnhoyTlsvcXVKZhmmcvkNwpApf9iubByc'
Sheet_NAME = 'データセット1!A'
Sheet_row = ":B"
RANGE_NAME = Sheet_NAME+Sheet_row
recentID_NM = ps.get_ss(SPREADSHEET_ID_NM,RANGE_NAME,service)

# %%
recentID_NM.columns
# Out:
# Index(['広告のコンテンツ', 'ID'], dtype='object')

# %%
recentID_NM['ID'] = recentID_NM['ID'].astype('int64')

# adinfoB にデータが1件以上あるか確認します
if len(adinfoB) > 0:
    # データがある場合は、最初のtenki_idに一致するインデックスを取得します
    target_id = adinfoB['tenki_id'].iloc[0]
    matching_index_NM = recentID_NM[recentID_NM["ID"] == target_id].index
else:
    # データがない場合は、空のリストを作成しておきます
    matching_index_NM = []
    print("adinfoBに条件に一致するデータが存在しませんでした。")
# Out:
# adinfoBに条件に一致するデータが存在しませんでした。

# %%
adinfoB = adinfoB[["広告ID","tenki_id"]]

# %%
adinfoB
# Out:
# Empty DataFrame
# Columns: [広告ID, tenki_id]
# Index: []

# %%
adinfoB["tenki_id"] = adinfoB["tenki_id"].astype(str) 

adinfoB.replace([np.inf, -np.inf], np.nan, inplace=True)
adinfoB = adinfoB.values.tolist()

# %%
# matching_index_NM[0]+1

# %%
# #NMシートにコピペ
# SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly',
#           'https://www.googleapis.com/auth/spreadsheets']
# json_path = r"Z:\Users\suehara\Documents\python\analysis\python_ss\credentials.json"
# service = ps.get_auth(SCOPES,json_path)
# SPREADSHEET_ID_NM = '1YRjsfJ76yfAnhoyTlsvcXVKZhmmcvkNwpApf9iubByc'
# Sheet_NAME = 'データセット1!A'
# Sheet_row = str(matching_index_NM[0]+1)
# RANGE_NAME = Sheet_NAME+Sheet_row
# ps.update_ss(SPREADSHEET_ID_NM,RANGE_NAME,adinfoB,service)
